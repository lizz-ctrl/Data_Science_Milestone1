# %% [markdown]
# ### Task 1

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Data indlæses med pandas .read_ccv

# %%
df = pd.read_csv('https://raw.githubusercontent.com/several27/FakeNewsCorpus/master/news_sample.csv')
## print(df)

# %% [markdown]
# Prøver at ryde op i data

# %%
df.head(2) # Laver et overskueligt oversigt over data
# Out:
#    Unnamed: 0   id             domain        type  \
# 0           0  141            awm.com  unreliable
# 1           1  256  beforeitsnews.com        fake
#
#                                                  url  \
# 0  http://awm.com/church-congregation-brings-gift...
# 1  http://beforeitsnews.com/awakening-start-here/...
#
#                                              content  \
# 0  Sometimes the power of Christmas will make you...
# 1  AWAKENING OF 12 STRANDS of DNA – “Reconnecting...
#
#                    scraped_at                 inserted_at  \
# 0  2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
# 1  2018-01-25 16:17:44.789555  2018-02-02 01:19:41.756632
#
#                    updated_at  \
# 0  2018-02-02 01:19:41.756664
# 1  2018-02-02 01:19:41.756664
#
#                                                title       authors  keywords  \
# 0  Church Congregation Brings Gift to Waitresses ...   Ruth Harris       NaN
# ...

# %% [markdown]
# Fjerner colloner som virker irrelevante

# %%
to_drop = ['summary','Unnamed: 0', 'keywords','inserted_at', 'updated_at', 'scraped_at']
# alt data er lagt ind den samme dag: 2018-02-02 og er ikke blevet opdaeret efterfølgende
# alt data er blevet scraped den samme dag: 2018-02-02
df_new = df.drop(to_drop, axis=1)
df_new.head(250)
# Out:
#         id                domain        type  \
# 0      141               awm.com  unreliable
# 1      256     beforeitsnews.com        fake
# 2      700           cnnnext.com  unreliable
# 3      768               awm.com  unreliable
# 4      791  bipartisanreport.com   clickbait
# ..     ...                   ...         ...
# 245  39259     beforeitsnews.com        fake
# 246  39468     beforeitsnews.com        fake
# 247  39477       www.newsmax.com         NaN
# 248  39550       www.newsmax.com         NaN
# 249  39558       www.newsmax.com         NaN
#
#                                                    url  \
# 0    http://awm.com/church-congregation-brings-gift...
# 1    http://beforeitsnews.com/awakening-start-here/...
# 2    http://www.cnnnext.com/video/18526/never-hike-...
# 3    http://awm.com/elusive-alien-of-the-sea-caught...
# 4    http://bipartisanreport.com/2018/01/21/trumps-...
# ..                                                 ...
# ...

# %%
## Udtagelse af bestemt type
df.loc[0:, 'type'].head(10)
# Out:
# 0    unreliable
# 1          fake
# 2    unreliable
# 3    unreliable
# 4     clickbait
# 5    unreliable
# 6    conspiracy
# 7          fake
# 8          fake
# 9    conspiracy
# Name: type, dtype: object

# %%
# ser antallet af NaN i hver coloner  
# print(df['type'].isnull())
print (df_new.isnull().sum())
# Out:
# id                    0
# domain                0
# type                 12
# url                   0
# content               0
# title                 0
# authors              80
# meta_keywords         0
# meta_description    196
# tags                223
# dtype: int64
